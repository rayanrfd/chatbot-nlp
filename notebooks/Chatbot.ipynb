# %% [markdown]
# imports

# %%
import transformers
from transformers import pipeline
import requests
from bs4 import BeautifulSoup
import os
import ftfy
import re  
from langchain.text_splitter import RecursiveCharacterTextSplitter
from transformers import AutoTokenizer
from transformers import AutoModel
import faiss
import numpy as np
import tiktoken
from sentence_transformers import SentenceTransformer
import json
import torch
from tqdm import tqdm
import ollama

# %% [markdown]
# Preparer les donnees (Documentation de Python)

# %%
# BASE_URL = "https://docs.python.org/3/"
# INDEX_URL = BASE_URL + "genindex-all.html"

# HEADERS = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
# }

# OUTPUT_FOLDER = "python_docs_cleaned"
# os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# def get_all_doc_links():
#     response = requests.get(INDEX_URL, headers=HEADERS)
#     response.encoding = "utf-8"
#     if response.status_code != 200:
#         print("Failed to fetch index page")
#         return []

#     soup = BeautifulSoup(response.text, "html.parser")

#     links = []
#     for a in soup.select("a"):
#         href = a.get("href", "")
#         if href.startswith("library/") or href.startswith("tutorial/") or href.startswith("reference/"):
#             full_url = BASE_URL + href
#             links.append(full_url)

#     return list(set(links))  

# def clean_text(text):
#     text = ftfy.fix_text(text)  
#     text = re.sub(r"\n{3,}", "\n\n", text)  
#     text = re.sub(r"([^\n])\n([^\n])", r"\1 \2", text)  
#     return text.strip()

# def scrape_page(url):
#     response = requests.get(url, headers=HEADERS)
#     response.encoding = "utf-8"
#     if response.status_code != 200:
#         return None

#     soup = BeautifulSoup(response.text, "html.parser")

#     title = soup.find("h1")
#     title_text = title.get_text(strip=True) if title else "No Title"

#     content = ""
#     for para in soup.select("p, li, pre"):  
#         text = para.get_text(separator=" ", strip=True)
#         text = clean_text(text)  
#         content += text + "\n\n"  

#     return title_text, content.strip()

# def scrape_and_save():
#     doc_links = get_all_doc_links()
#     print(f"Found {len(doc_links)} documentation pages.")

#     for i, url in enumerate(doc_links):
#         print(f"Scraping {i+1}/{len(doc_links)}: {url}")
#         title, content = scrape_page(url)
#         if content:
#             filename = f"{title.replace(' ', '_').replace('/', '_')}.txt"
#             filepath = os.path.join(OUTPUT_FOLDER, filename)

#             with open(filepath, "w", encoding="utf-8") as f:
#                 f.write(f"Title: {title}\nURL: {url}\n\n{content}")

#     print(f" Saved {len(doc_links)} cleaned pages in '{OUTPUT_FOLDER}'.")

# if __name__ == "__main__":
#     scrape_and_save()
# Out:
# Found 11746 documentation pages.
# Scraping 1/11746: https://docs.python.org/3/library/posix.html#index-1
# Scraping 2/11746: https://docs.python.org/3/library/importlib.html#importlib.abc.Traversable.is_file
# Scraping 3/11746: https://docs.python.org/3/library/asyncio-queue.html#asyncio.Queue.join
# Scraping 4/11746: https://docs.python.org/3/library/py_compile.html#cmdoption-python-m-py_compile-q
# Scraping 5/11746: https://docs.python.org/3/library/exceptions.html#SyntaxError.lineno
# Scraping 6/11746: https://docs.python.org/3/library/dis.html#opcode-LOAD_FAST
# Scraping 7/11746: https://docs.python.org/3/library/symtable.html#symtable.SymbolTable.lookup
# Scraping 8/11746: https://docs.python.org/3/library/contextvars.html#contextvars.Token
# Scraping 9/11746: https://docs.python.org/3/library/functions.html#index-9
# Scraping 10/11746: https://docs.python.org/3/library/multiprocessing.html#index-0
# Scraping 11/11746: https://docs.python.org/3/reference/datamodel.html#index-51
# Scraping 12/11746: https://docs.python.org/3/library/uuid.html#index-2
# Scraping 13/11746: https://docs.python.org/3/reference/datamodel.html#type.__subclasses__
# Scraping 14/11746: https://docs.python.org/3/library/locale.html#locale.ABDAY_3
# Scraping 15/11746: https://docs.python.org/3/library/glob.html#index-0
# Scraping 16/11746: https://docs.python.org/3/library/turtle.html#turtle.fillcolor
# Scraping 17/11746: https://docs.python.org/3/library/array.html#array.array.byteswap
# Scraping 18/11746: https://docs.python.org/3/library/exceptions.html#TypeError
# Scraping 19/11746: https://docs.python.org/3/library/re.html#re.Pattern.match
# Scraping 20/11746: https://docs.python.org/3/library/os.html#os.MFD_HUGE_512KB
# Scraping 21/11746: https://docs.python.org/3/library/curses.html#curses.tparm
# Scraping 22/11746: https://docs.python.org/3/library/dis.html#opcode-YIELD_VALUE
# Scraping 23/11746: https://docs.python.org/3/library/wave.html#wave.Wave_write.setframerate
# Scraping 24/11746: https://docs.python.org/3/library/wsgiref.html#index-17
# Scraping 25/11746: https://docs.python.org/3/library/ipaddress.html#ipaddress.IPv4Interface.ip
# Scraping 26/11746: https://docs.python.org/3/library/functions.html#classmethod
# Scraping 27/11746: https://docs.python.org/3/library/ctypes.html#ctypes.c_void_p
# Scraping 28/11746: https://docs.python.org/3/library/doctest.html#doctest.TestResults.skipped
# Scraping 29/11746: https://docs.python.org/3/library/math.html#math.floor
# Scraping 30/11746: https://docs.python.org/3/library/os.html#os.getlogin
# Scraping 31/11746: https://docs.python.org/3/library/sys.monitoring.html#monitoring-event-JUMP
# Scraping 32/11746: https://docs.python.org/3/library/test.html#test.support.Matcher.match_value
# Scraping 33/11746: https://docs.python.org/3/library/pyexpat.html#xml.parsers.expat.errors.XML_ERROR_FEATURE_REQUIRES_XML_DTD
# Scraping 34/11746: https://docs.python.org/3/library/random.html#random.choice
# Scraping 35/11746: https://docs.python.org/3/library/os.html#os.listdrives
# Scraping 36/11746: https://docs.python.org/3/library/marshal.html#marshal.dumps
# Scraping 37/11746: https://docs.python.org/3/library/functools.html#functools.update_wrapper
# Scraping 38/11746: https://docs.python.org/3/library/wsgiref.html#wsgiref.types.StartResponse
# Scraping 39/11746: https://docs.python.org/3/library/calendar.html#calendar.SEPTEMBER
# Scraping 40/11746: https://docs.python.org/3/library/os.html#os.F_TEST
# Scraping 41/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Notebook.insert
# Scraping 42/11746: https://docs.python.org/3/library/pyexpat.html#xml.parsers.expat.errors.XML_ERROR_INCORRECT_ENCODING
# Scraping 43/11746: https://docs.python.org/3/library/weakref.html#module-weakref
# Scraping 44/11746: https://docs.python.org/3/library/socket.html#socket.AF_DIVERT
# Scraping 45/11746: https://docs.python.org/3/library/functions.html#eval
# Scraping 46/11746: https://docs.python.org/3/library/argparse.html#argparse.ArgumentParser.convert_arg_line_to_args
# Scraping 47/11746: https://docs.python.org/3/library/importlib.resources.abc.html#importlib.resources.abc.ResourceReader.contents
# Scraping 48/11746: https://docs.python.org/3/library/multiprocessing.html#multiprocessing.pool.Pool.terminate
# Scraping 49/11746: https://docs.python.org/3/library/functions.html#max
# Scraping 50/11746: https://docs.python.org/3/library/select.html#select.kevent.data
# Scraping 51/11746: https://docs.python.org/3/library/signal.html#signal.SIGTERM
# Scraping 52/11746: https://docs.python.org/3/library/urllib.request.html#urllib.request.FancyURLopener.prompt_user_passwd
# Scraping 53/11746: https://docs.python.org/3/library/optparse.html#optparse.OptionParser.get_version
# Scraping 54/11746: https://docs.python.org/3/reference/datamodel.html#object.__aiter__
# Scraping 55/11746: https://docs.python.org/3/library/test.html#test.support.import_helper.CleanImport
# Scraping 56/11746: https://docs.python.org/3/library/functions.html#breakpoint
# Scraping 57/11746: https://docs.python.org/3/library/dis.html#dis.hasname
# Scraping 58/11746: https://docs.python.org/3/library/asyncio-future.html#asyncio.wrap_future
# Scraping 59/11746: https://docs.python.org/3/library/http.cookies.html#index-1
# Scraping 60/11746: https://docs.python.org/3/reference/datamodel.html#index-62
# Scraping 61/11746: https://docs.python.org/3/library/curses.ascii.html#curses.ascii.iscntrl
# Scraping 62/11746: https://docs.python.org/3/library/test.html#test.support.os_helper.FakePath
# Scraping 63/11746: https://docs.python.org/3/library/os.html#os.initgroups
# Scraping 64/11746: https://docs.python.org/3/library/stdtypes.html#range.stop
# Scraping 65/11746: https://docs.python.org/3/library/socket.html#socket.AF_UNIX
# Scraping 66/11746: https://docs.python.org/3/library/codecs.html#index-11
# Scraping 67/11746: https://docs.python.org/3/library/http.html#index-46
# Scraping 68/11746: https://docs.python.org/3/library/decimal.html#decimal.Context.to_integral_exact
# Scraping 69/11746: https://docs.python.org/3/library/re.html#re.PatternError.pattern
# Scraping 70/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Widget.state
# Scraping 71/11746: https://docs.python.org/3/library/inspect.html#inspect.CO_OPTIMIZED
# Scraping 72/11746: https://docs.python.org/3/library/inspect.html#inspect.Parameter.kind
# Scraping 73/11746: https://docs.python.org/3/library/tokenize.html#tokenize.detect_encoding
# Scraping 74/11746: https://docs.python.org/3/library/ssl.html#ssl.SSLSocket.session
# Scraping 75/11746: https://docs.python.org/3/library/dbm.html#dbm.sqlite3.open
# Scraping 76/11746: https://docs.python.org/3/library/stdtypes.html#memoryview.readonly
# Scraping 77/11746: https://docs.python.org/3/library/urllib.request.html#urllib.request.getproxies
# Scraping 78/11746: https://docs.python.org/3/library/http.cookies.html#http.cookies.CookieError
# Scraping 79/11746: https://docs.python.org/3/library/asyncio-protocol.html#asyncio.BufferedProtocol
# Scraping 80/11746: https://docs.python.org/3/library/email.headerregistry.html#email.headerregistry.AddressHeader.groups
# Scraping 81/11746: https://docs.python.org/3/library/mailbox.html#mailbox.MH.close
# Scraping 82/11746: https://docs.python.org/3/library/logging.handlers.html#logging.handlers.SocketHandler.makeSocket
# Scraping 83/11746: https://docs.python.org/3/library/http.cookiejar.html#index-8
# Scraping 84/11746: https://docs.python.org/3/library/socketserver.html#socketserver.BaseServer.handle_timeout
# Scraping 85/11746: https://docs.python.org/3/library/ctypes.html#ctypes._CData.from_param
# Scraping 86/11746: https://docs.python.org/3/library/xml.dom.html#xml.dom.Node.previousSibling
# Scraping 87/11746: https://docs.python.org/3/library/xml.dom.html#xml.dom.IndexSizeErr
# Scraping 88/11746: https://docs.python.org/3/reference/datamodel.html#object.__ror__
# Scraping 89/11746: https://docs.python.org/3/library/stdtypes.html#index-8
# Scraping 90/11746: https://docs.python.org/3/library/email.examples.html#index-0
# Scraping 91/11746: https://docs.python.org/3/library/importlib.html#importlib.util._incompatible_extension_module_restrictions
# Scraping 92/11746: https://docs.python.org/3/library/ipaddress.html#ipaddress.IPv6Network.compressed
# Scraping 93/11746: https://docs.python.org/3/library/ipaddress.html#ipaddress.IPv6Network.with_prefixlen
# Scraping 94/11746: https://docs.python.org/3/library/math.html#math.log10
# Scraping 95/11746: https://docs.python.org/3/library/msvcrt.html#msvcrt.getwch
# Scraping 96/11746: https://docs.python.org/3/library/xml.sax.reader.html#xml.sax.xmlreader.AttributesNS.getQNames
# Scraping 97/11746: https://docs.python.org/3/library/email.compat32-message.html#index-11
# Scraping 98/11746: https://docs.python.org/3/library/selectors.html#index-0
# Scraping 99/11746: https://docs.python.org/3/library/wsgiref.html#wsgiref.simple_server.WSGIRequestHandler
# Scraping 100/11746: https://docs.python.org/3/library/tkinter.html#tkinter.Tk.master
# Scraping 101/11746: https://docs.python.org/3/library/re.html#index-9
# Scraping 102/11746: https://docs.python.org/3/library/decimal.html#decimal.Context.is_canonical
# Scraping 103/11746: https://docs.python.org/3/library/curses.html#curses.pair_content
# Scraping 104/11746: https://docs.python.org/3/library/time.html#time.perf_counter
# Scraping 105/11746: https://docs.python.org/3/library/os.html#index-51
# Scraping 106/11746: https://docs.python.org/3/library/optparse.html#optparse.Option.callback
# Scraping 107/11746: https://docs.python.org/3/library/ast.html#ast.NodeVisitor.visit_Constant
# Scraping 108/11746: https://docs.python.org/3/library/email.errors.html#email.errors.NoBoundaryInMultipartDefect
# Scraping 109/11746: https://docs.python.org/3/library/io.html#io.FileIO.mode
# Scraping 110/11746: https://docs.python.org/3/library/enum.html#enum.Enum.__init_subclass__
# Scraping 111/11746: https://docs.python.org/3/library/msvcrt.html#msvcrt.getch
# Scraping 112/11746: https://docs.python.org/3/library/tkinter.font.html#tkinter.font.ROMAN
# Scraping 113/11746: https://docs.python.org/3/reference/expressions.html#index-5
# Scraping 114/11746: https://docs.python.org/3/reference/executionmodel.html#index-13
# Scraping 115/11746: https://docs.python.org/3/library/fileinput.html#fileinput.nextfile
# Scraping 116/11746: https://docs.python.org/3/library/test.html#test.support.os_helper.TESTFN
# Scraping 117/11746: https://docs.python.org/3/library/json.html#index-1
# Scraping 118/11746: https://docs.python.org/3/library/urllib.robotparser.html#urllib.robotparser.RobotFileParser.can_fetch
# Scraping 119/11746: https://docs.python.org/3/reference/datamodel.html#object.__setitem__
# Scraping 120/11746: https://docs.python.org/3/library/sys.html#sys.float_info.max
# Scraping 121/11746: https://docs.python.org/3/library/xml.sax.reader.html#xml.sax.xmlreader.Locator
# Scraping 122/11746: https://docs.python.org/3/library/tkinter.html#index-2
# Scraping 123/11746: https://docs.python.org/3/library/stdtypes.html#str.title
# Scraping 124/11746: https://docs.python.org/3/library/typing.html#index-1
# Scraping 125/11746: https://docs.python.org/3/library/re.html#re.U
# Scraping 126/11746: https://docs.python.org/3/library/exceptions.html#FileNotFoundError
# Scraping 127/11746: https://docs.python.org/3/library/urllib.request.html#urllib.request.ProxyHandler
# Scraping 128/11746: https://docs.python.org/3/library/email.headerregistry.html#index-1
# Scraping 129/11746: https://docs.python.org/3/library/importlib.html#importlib.machinery.SourcelessFileLoader.get_code
# Scraping 130/11746: https://docs.python.org/3/library/errno.html#errno.EFTYPE
# Scraping 131/11746: https://docs.python.org/3/library/base64.html#base64.encodebytes
# Scraping 132/11746: https://docs.python.org/3/library/gettext.html#gettext.NullTranslations.ngettext
# Scraping 133/11746: https://docs.python.org/3/library/smtplib.html#index-6
# Scraping 134/11746: https://docs.python.org/3/library/random.html#random.choices
# Scraping 135/11746: https://docs.python.org/3/library/ipaddress.html#ipaddress.IPv4Address.exploded
# Scraping 136/11746: https://docs.python.org/3/library/constants.html#credits
# Scraping 137/11746: https://docs.python.org/3/library/re.html#re.VERBOSE
# Scraping 138/11746: https://docs.python.org/3/reference/datamodel.html#codeobject.co_freevars
# Scraping 139/11746: https://docs.python.org/3/library/xml.dom.html#xml.dom.Document.createProcessingInstruction
# Scraping 140/11746: https://docs.python.org/3/library/curses.html#curses.init_pair
# Scraping 141/11746: https://docs.python.org/3/library/ssl.html#ssl.OP_NO_SSLv3
# Scraping 142/11746: https://docs.python.org/3/library/http.html#index-73
# Scraping 143/11746: https://docs.python.org/3/library/array.html#array.array.clear
# Scraping 144/11746: https://docs.python.org/3/library/types.html#types.ClassMethodDescriptorType
# Scraping 145/11746: https://docs.python.org/3/library/errno.html#errno.EINPROGRESS
# Scraping 146/11746: https://docs.python.org/3/library/ftplib.html#ftplib.FTP_TLS.ccc
# Scraping 147/11746: https://docs.python.org/3/library/socket.html#socket.getprotobyname
# Scraping 148/11746: https://docs.python.org/3/library/gc.html#gc.DEBUG_COLLECTABLE
# Scraping 149/11746: https://docs.python.org/3/library/curses.html#curses.window.clearok
# Scraping 150/11746: https://docs.python.org/3/library/os.html#os.fstat
# Scraping 151/11746: https://docs.python.org/3/library/select.html#select.poll.modify
# Scraping 152/11746: https://docs.python.org/3/library/dis.html#opcode-IS_OP
# Scraping 153/11746: https://docs.python.org/3/library/asyncio-policy.html#asyncio.SafeChildWatcher
# Scraping 154/11746: https://docs.python.org/3/library/xml.sax.handler.html#xml.sax.handler.LexicalHandler.comment
# Scraping 155/11746: https://docs.python.org/3/reference/simple_stmts.html#index-21
# Scraping 156/11746: https://docs.python.org/3/library/pkgutil.html#index-4
# Scraping 157/11746: https://docs.python.org/3/library/sys.html#sys.thread_info.name
# Scraping 158/11746: https://docs.python.org/3/library/tkinter.html#index-1
# Scraping 159/11746: https://docs.python.org/3/library/pyexpat.html#xml.parsers.expat.errors.XML_ERROR_CANT_CHANGE_FEATURE_ONCE_PARSING
# Scraping 160/11746: https://docs.python.org/3/library/typing.html#index-25
# Scraping 161/11746: https://docs.python.org/3/library/functions.html#hasattr
# Scraping 162/11746: https://docs.python.org/3/library/shlex.html#shlex.split
# Scraping 163/11746: https://docs.python.org/3/library/stdtypes.html#str.index
# Scraping 164/11746: https://docs.python.org/3/library/http.server.html#http.server.BaseHTTPRequestHandler.MessageClass
# Scraping 165/11746: https://docs.python.org/3/library/pickle.html#pickle.Pickler.persistent_id
# Scraping 166/11746: https://docs.python.org/3/library/subprocess.html#subprocess.STARTUPINFO.dwFlags
# Scraping 167/11746: https://docs.python.org/3/library/email.message.html#email.message.EmailMessage.make_alternative
# Scraping 168/11746: https://docs.python.org/3/library/stdtypes.html#definition.__name__
# Scraping 169/11746: https://docs.python.org/3/library/cgi.html#index-0
# Scraping 170/11746: https://docs.python.org/3/library/datetime.html#datetime.time.min
# Scraping 171/11746: https://docs.python.org/3/library/os.html#os.sched_param
# Scraping 172/11746: https://docs.python.org/3/library/asyncio-sync.html#asyncio.Condition.wait_for
# Scraping 173/11746: https://docs.python.org/3/library/urllib.request.html#urllib.request.OpenerDirector
# Scraping 174/11746: https://docs.python.org/3/library/email.policy.html#email.policy.Compat32.header_fetch_parse
# Scraping 175/11746: https://docs.python.org/3/library/email.header.html#index-8
# Scraping 176/11746: https://docs.python.org/3/library/os.html#os.lchown
# Scraping 177/11746: https://docs.python.org/3/library/http.server.html#index-3
# Scraping 178/11746: https://docs.python.org/3/library/collections.abc.html#collections.abc.AsyncIterator
# Scraping 179/11746: https://docs.python.org/3/library/email.errors.html#module-email.errors
# Scraping 180/11746: https://docs.python.org/3/library/poplib.html#index-2
# Scraping 181/11746: https://docs.python.org/3/library/collections.html#index-1
# Scraping 182/11746: https://docs.python.org/3/library/codecs.html#codecs.CodecInfo.streamwriter
# Scraping 183/11746: https://docs.python.org/3/library/zipfile.html#cmdoption-zipfile-create
# Scraping 184/11746: https://docs.python.org/3/library/typing.html#typing.TypeVar.__name__
# Scraping 185/11746: https://docs.python.org/3/library/os.html#os.TFD_TIMER_ABSTIME
# Scraping 186/11746: https://docs.python.org/3/library/re.html#re.Pattern.groupindex
# Scraping 187/11746: https://docs.python.org/3/library/threading.html#threading.Event.clear
# Scraping 188/11746: https://docs.python.org/3/library/sys.html#sys.getswitchinterval
# Scraping 189/11746: https://docs.python.org/3/library/email.compat32-message.html#index-9
# Scraping 190/11746: https://docs.python.org/3/library/os.html#os.chown
# Scraping 191/11746: https://docs.python.org/3/library/imaplib.html#imaplib.IMAP4.namespace
# Scraping 192/11746: https://docs.python.org/3/library/datetime.html#datetime.datetime.fromordinal
# Scraping 193/11746: https://docs.python.org/3/library/inspect.html#inspect.getmembers
# Scraping 194/11746: https://docs.python.org/3/library/ast.html#ast.MatchClass
# Scraping 195/11746: https://docs.python.org/3/library/xml.etree.elementtree.html#xml.etree.ElementTree.Element.tail
# Scraping 196/11746: https://docs.python.org/3/library/contextvars.html#contextvars.Token.old_value
# Scraping 197/11746: https://docs.python.org/3/library/signal.html#index-0
# Scraping 198/11746: https://docs.python.org/3/library/email.header.html#email.header.Header.__ne__
# Scraping 199/11746: https://docs.python.org/3/library/difflib.html#module-difflib
# Scraping 200/11746: https://docs.python.org/3/library/email.parser.html#email.parser.BytesFeedParser
# Scraping 201/11746: https://docs.python.org/3/library/unittest.html#unittest.TestResult.unexpectedSuccesses
# Scraping 202/11746: https://docs.python.org/3/library/errno.html#errno.EBADMSG
# Scraping 203/11746: https://docs.python.org/3/library/inspect.html#inspect.BoundArguments.args
# Scraping 204/11746: https://docs.python.org/3/library/inspect.html#inspect.BoundArguments
# Scraping 205/11746: https://docs.python.org/3/library/typing.html#typing.Counter
# Scraping 206/11746: https://docs.python.org/3/library/typing.html#typing.no_type_check_decorator
# Scraping 207/11746: https://docs.python.org/3/library/urllib.request.html#urllib.request.CacheFTPHandler.setMaxConns
# Scraping 208/11746: https://docs.python.org/3/library/http.cookies.html#index-7
# Scraping 209/11746: https://docs.python.org/3/library/urllib.parse.html#urllib.parse.unwrap
# Scraping 210/11746: https://docs.python.org/3/library/ipaddress.html#ipaddress.IPv6Interface.with_prefixlen
# Scraping 211/11746: https://docs.python.org/3/library/statistics.html#statistics.geometric_mean
# Scraping 212/11746: https://docs.python.org/3/library/xml.dom.minidom.html#xml.dom.minidom.Node.unlink
# Scraping 213/11746: https://docs.python.org/3/library/socket.html#socket.socket.recv
# Scraping 214/11746: https://docs.python.org/3/library/locale.html#locale.localeconv
# Scraping 215/11746: https://docs.python.org/3/library/subprocess.html#subprocess.CompletedProcess.returncode
# Scraping 216/11746: https://docs.python.org/3/library/winreg.html#winreg.KEY_ALL_ACCESS
# Scraping 217/11746: https://docs.python.org/3/library/stat.html#stat.S_IMODE
# Scraping 218/11746: https://docs.python.org/3/library/unittest.html#unittest.removeHandler
# Scraping 219/11746: https://docs.python.org/3/library/calendar.html#calendar.Calendar.setfirstweekday
# Scraping 220/11746: https://docs.python.org/3/reference/datamodel.html#module.__path__
# Scraping 221/11746: https://docs.python.org/3/library/http.client.html#http.client.HTTPSConnection
# Scraping 222/11746: https://docs.python.org/3/library/urllib.request.html#urllib.request.HTTPDigestAuthHandler
# Scraping 223/11746: https://docs.python.org/3/library/select.html#index-4
# Scraping 224/11746: https://docs.python.org/3/library/glob.html#index-1
# Scraping 225/11746: https://docs.python.org/3/library/symtable.html#symtable.SymbolTable.get_type
# Scraping 226/11746: https://docs.python.org/3/library/pydoc.html#index-2
# Scraping 227/11746: https://docs.python.org/3/library/sys.html#sys.implementation
# Scraping 228/11746: https://docs.python.org/3/library/curses.html#curses.KEY_END
# Scraping 229/11746: https://docs.python.org/3/reference/lexical_analysis.html#index-32
# Scraping 230/11746: https://docs.python.org/3/library/os.html#os.eventfd_read
# Scraping 231/11746: https://docs.python.org/3/reference/compound_stmts.html#index-12
# Scraping 232/11746: https://docs.python.org/3/library/shelve.html#shelve.open
# Scraping 233/11746: https://docs.python.org/3/library/signal.html#signal.sigpending
# Scraping 234/11746: https://docs.python.org/3/library/ast.html#ast.unparse
# Scraping 235/11746: https://docs.python.org/3/library/calendar.html#calendar.JANUARY
# Scraping 236/11746: https://docs.python.org/3/library/signal.html#index-1
# Scraping 237/11746: https://docs.python.org/3/library/sys.html#sys.__stdout__
# Scraping 238/11746: https://docs.python.org/3/library/poplib.html#poplib.POP3
# Scraping 239/11746: https://docs.python.org/3/library/ftplib.html#ftplib.FTP.set_debuglevel
# Scraping 240/11746: https://docs.python.org/3/library/wsgiref.html#index-5
# Scraping 241/11746: https://docs.python.org/3/library/importlib.html#importlib.abc.ExecutionLoader
# Scraping 242/11746: https://docs.python.org/3/library/inspect.html#inspect.FrameInfo.filename
# Scraping 243/11746: https://docs.python.org/3/library/exceptions.html#BaseException.add_note
# Scraping 244/11746: https://docs.python.org/3/library/cmath.html#cmath.atan
# Scraping 245/11746: https://docs.python.org/3/library/stdtypes.html#int.is_integer
# Scraping 246/11746: https://docs.python.org/3/library/sqlite3.html#sqlite3.IntegrityError
# Scraping 247/11746: https://docs.python.org/3/library/http.html#index-11
# Scraping 248/11746: https://docs.python.org/3/library/poplib.html#poplib.POP3.stls
# Scraping 249/11746: https://docs.python.org/3/library/curses.html#curses.window.overwrite
# Scraping 250/11746: https://docs.python.org/3/library/token.html#token.DOUBLESTAREQUAL
# Scraping 251/11746: https://docs.python.org/3/library/cmath.html#index-0
# Scraping 252/11746: https://docs.python.org/3/library/symtable.html#symtable.Function.get_globals
# Scraping 253/11746: https://docs.python.org/3/library/cmath.html#cmath.tan
# Scraping 254/11746: https://docs.python.org/3/library/random.html#random.betavariate
# Scraping 255/11746: https://docs.python.org/3/library/curses.html#curses.nl
# Scraping 256/11746: https://docs.python.org/3/library/importlib.html#importlib.abc.SourceLoader.set_data
# Scraping 257/11746: https://docs.python.org/3/library/asyncio-protocol.html#asyncio.ReadTransport
# Scraping 258/11746: https://docs.python.org/3/library/zipapp.html#index-0
# Scraping 259/11746: https://docs.python.org/3/library/gettext.html#index-2
# Scraping 260/11746: https://docs.python.org/3/library/email.mime.html#module-email.mime.base
# Scraping 261/11746: https://docs.python.org/3/library/errno.html#errno.ENOMEM
# Scraping 262/11746: https://docs.python.org/3/library/html.entities.html#html.entities.name2codepoint
# Scraping 263/11746: https://docs.python.org/3/library/email.compat32-message.html#email.message.Message.__delitem__
# Scraping 264/11746: https://docs.python.org/3/library/xml.etree.elementtree.html#xml.etree.ElementTree.ParseError
# Scraping 265/11746: https://docs.python.org/3/library/tracemalloc.html#tracemalloc.Filter.filename_pattern
# Scraping 266/11746: https://docs.python.org/3/library/dis.html#dis.hasjabs
# Scraping 267/11746: https://docs.python.org/3/library/pdb.html#pdbcommand-disable
# Scraping 268/11746: https://docs.python.org/3/library/xml.dom.html#index-0
# Scraping 269/11746: https://docs.python.org/3/library/collections.html#collections.deque.maxlen
# Scraping 270/11746: https://docs.python.org/3/library/stdtypes.html#bytes.rindex
# Scraping 271/11746: https://docs.python.org/3/library/os.html#os.POSIX_FADV_NOREUSE
# Scraping 272/11746: https://docs.python.org/3/library/os.html#os.O_EXLOCK
# Scraping 273/11746: https://docs.python.org/3/library/os.html#os.O_NDELAY
# Scraping 274/11746: https://docs.python.org/3/library/contextlib.html#contextlib.ExitStack.push
# Scraping 275/11746: https://docs.python.org/3/library/mailbox.html#mailbox.BabylMessage.set_visible
# Scraping 276/11746: https://docs.python.org/3/library/operator.html#operator.__inv__
# Scraping 277/11746: https://docs.python.org/3/library/csv.html#csv.csvreader.line_num
# Scraping 278/11746: https://docs.python.org/3/library/test.html#test.support.set_memlimit
# Scraping 279/11746: https://docs.python.org/3/library/decimal.html#decimal.Decimal.max
# Scraping 280/11746: https://docs.python.org/3/library/email.message.html#email.message.EmailMessage.__str__
# Scraping 281/11746: https://docs.python.org/3/library/ast.html#ast.AsyncFor
# Scraping 282/11746: https://docs.python.org/3/library/faulthandler.html#faulthandler.enable
# Scraping 283/11746: https://docs.python.org/3/library/http.cookiejar.html#http.cookiejar.DefaultCookiePolicy.rfc2109_as_netscape
# Scraping 284/11746: https://docs.python.org/3/library/locale.html#locale.ABDAY_6
# Scraping 285/11746: https://docs.python.org/3/library/timeit.html#cmdoption-timeit-v
# Scraping 286/11746: https://docs.python.org/3/library/winreg.html#winreg.HKEY_DYN_DATA
# Scraping 287/11746: https://docs.python.org/3/library/sqlite3.html#index-6
# Scraping 288/11746: https://docs.python.org/3/library/cmd.html#cmd.Cmd.undoc_header
# Scraping 289/11746: https://docs.python.org/3/library/test.html#test.support.TEST_HTTP_URL
# Scraping 290/11746: https://docs.python.org/3/library/socketserver.html#socketserver.BaseServer.server_activate
# Scraping 291/11746: https://docs.python.org/3/library/wsgiref.html#wsgiref.types.InputStream
# Scraping 292/11746: https://docs.python.org/3/reference/expressions.html#index-15
# Scraping 293/11746: https://docs.python.org/3/library/pyexpat.html#xml.parsers.expat.xmlparser.EndDoctypeDeclHandler
# Scraping 294/11746: https://docs.python.org/3/library/winreg.html#winreg.EnableReflectionKey
# Scraping 295/11746: https://docs.python.org/3/library/datetime.html#datetime.time.replace
# Scraping 296/11746: https://docs.python.org/3/library/email.errors.html#email.errors.InvalidBase64LengthDefect
# Scraping 297/11746: https://docs.python.org/3/reference/compound_stmts.html#index-20
# Scraping 298/11746: https://docs.python.org/3/library/functions.html#oct
# Scraping 299/11746: https://docs.python.org/3/library/sys.html#sys.float_repr_style
# Scraping 300/11746: https://docs.python.org/3/library/zlib.html#zlib.Decompress.unconsumed_tail
# Scraping 301/11746: https://docs.python.org/3/library/functions.html#issubclass
# Scraping 302/11746: https://docs.python.org/3/library/token.html#token.ATEQUAL
# Scraping 303/11746: https://docs.python.org/3/library/email.compat32-message.html#index-6
# Scraping 304/11746: https://docs.python.org/3/library/errno.html#errno.ERPCMISMATCH
# Scraping 305/11746: https://docs.python.org/3/library/termios.html#termios.TCSAFLUSH
# Scraping 306/11746: https://docs.python.org/3/library/xml.dom.html#xml.dom.Node.replaceChild
# Scraping 307/11746: https://docs.python.org/3/library/binascii.html#binascii.crc32
# Scraping 308/11746: https://docs.python.org/3/library/array.html#array.array.fromfile
# Scraping 309/11746: https://docs.python.org/3/library/pickletools.html#module-pickletools
# Scraping 310/11746: https://docs.python.org/3/library/inspect.html#inspect.getsourcelines
# Scraping 311/11746: https://docs.python.org/3/library/os.html#index-12
# Scraping 312/11746: https://docs.python.org/3/library/sys.html#sys.__unraisablehook__
# Scraping 313/11746: https://docs.python.org/3/library/sys.monitoring.html#sys.monitoring.use_tool_id
# Scraping 314/11746: https://docs.python.org/3/library/os.html#os.O_FSYNC
# Scraping 315/11746: https://docs.python.org/3/library/socketserver.html#socketserver.BaseServer.address_family
# Scraping 316/11746: https://docs.python.org/3/library/zipfile.html#zipfile.ZipFile.getinfo
# Scraping 317/11746: https://docs.python.org/3/library/stdtypes.html#str.find
# Scraping 318/11746: https://docs.python.org/3/library/tarfile.html#tarfile.TarFile.getmember
# Scraping 319/11746: https://docs.python.org/3/reference/datamodel.html#index-4
# Scraping 320/11746: https://docs.python.org/3/library/tracemalloc.html#tracemalloc.StatisticDiff.count
# Scraping 321/11746: https://docs.python.org/3/library/codecs.html#codecs.StreamReader.readline
# Scraping 322/11746: https://docs.python.org/3/library/inspect.html#inspect.BufferFlags.RECORDS_RO
# Scraping 323/11746: https://docs.python.org/3/library/math.html#math.lgamma
# Scraping 324/11746: https://docs.python.org/3/library/traceback.html#traceback.TracebackException.format_exception_only
# Scraping 325/11746: https://docs.python.org/3/library/gzip.html#cmdoption-gzip-h
# Scraping 326/11746: https://docs.python.org/3/library/unittest.mock.html#unittest.mock.patch.multiple
# Scraping 327/11746: https://docs.python.org/3/library/operator.html#operator.contains
# Scraping 328/11746: https://docs.python.org/3/library/asyncio-protocol.html#asyncio.SubprocessTransport.close
# Scraping 329/11746: https://docs.python.org/3/reference/datamodel.html#index-19
# Scraping 330/11746: https://docs.python.org/3/reference/datamodel.html#index-71
# Scraping 331/11746: https://docs.python.org/3/library/pathlib.html#pathlib.PurePath.anchor
# Scraping 332/11746: https://docs.python.org/3/library/unittest.html#unittest.TestCase.addTypeEqualityFunc
# Scraping 333/11746: https://docs.python.org/3/reference/expressions.html#index-98
# Scraping 334/11746: https://docs.python.org/3/library/importlib.html#importlib.abc.TraversableResources.files
# Scraping 335/11746: https://docs.python.org/3/library/unittest.html#unittest.TestResult.failfast
# Scraping 336/11746: https://docs.python.org/3/reference/datamodel.html#index-94
# Scraping 337/11746: https://docs.python.org/3/library/stdtypes.html#index-13
# Scraping 338/11746: https://docs.python.org/3/library/xml.etree.elementtree.html#xml.etree.ElementTree.indent
# Scraping 339/11746: https://docs.python.org/3/reference/expressions.html#index-21
# Scraping 340/11746: https://docs.python.org/3/library/select.html#select.epoll.fileno
# Scraping 341/11746: https://docs.python.org/3/library/os.path.html#os.path.commonprefix
# Scraping 342/11746: https://docs.python.org/3/library/ctypes.html#ctypes.set_errno
# Scraping 343/11746: https://docs.python.org/3/library/pathlib.html#pathlib.PurePath.parser
# Scraping 344/11746: https://docs.python.org/3/library/turtle.html#turtle.backward
# Scraping 345/11746: https://docs.python.org/3/library/email.message.html#email.message.EmailMessage.make_related
# Scraping 346/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Style
# Scraping 347/11746: https://docs.python.org/3/library/winsound.html#winsound.PlaySound
# Scraping 348/11746: https://docs.python.org/3/library/shlex.html#shlex.shlex.debug
# Scraping 349/11746: https://docs.python.org/3/reference/import.html#index-12
# Scraping 350/11746: https://docs.python.org/3/library/string.html#string.Template.safe_substitute
# Scraping 351/11746: https://docs.python.org/3/library/doctest.html#doctest.DocTestParser.get_doctest
# Scraping 352/11746: https://docs.python.org/3/library/socket.html#socket.AF_HYPERV
# Scraping 353/11746: https://docs.python.org/3/library/dis.html#opcode-BUILD_SLICE
# Scraping 354/11746: https://docs.python.org/3/library/gettext.html#gettext.NullTranslations.install
# Scraping 355/11746: https://docs.python.org/3/library/ctypes.html#ctypes.c_size_t
# Scraping 356/11746: https://docs.python.org/3/library/errno.html#errno.ENOTSUP
# Scraping 357/11746: https://docs.python.org/3/library/signal.html#signal.SIGSTKFLT
# Scraping 358/11746: https://docs.python.org/3/library/dataclasses.html#index-0
# Scraping 359/11746: https://docs.python.org/3/library/stdtypes.html#bytearray.lstrip
# Scraping 360/11746: https://docs.python.org/3/reference/lexical_analysis.html#index-22
# Scraping 361/11746: https://docs.python.org/3/library/itertools.html#itertools.cycle
# Scraping 362/11746: https://docs.python.org/3/library/operator.html#operator.isub
# Scraping 363/11746: https://docs.python.org/3/reference/datamodel.html#object.__abs__
# Scraping 364/11746: https://docs.python.org/3/library/socketserver.html#socketserver.BaseRequestHandler.handle
# Scraping 365/11746: https://docs.python.org/3/library/threading.html#threading.enumerate
# Scraping 366/11746: https://docs.python.org/3/library/logging.html#logging.Logger.removeFilter
# Scraping 367/11746: https://docs.python.org/3/library/pathlib.html#pathlib.Path.read_bytes
# Scraping 368/11746: https://docs.python.org/3/reference/expressions.html#index-67
# Scraping 369/11746: https://docs.python.org/3/library/wsgiref.html#wsgiref.simple_server.make_server
# Scraping 370/11746: https://docs.python.org/3/library/exceptions.html#BaseExceptionGroup.exceptions
# Scraping 371/11746: https://docs.python.org/3/library/exceptions.html#BaseExceptionGroup.split
# Scraping 372/11746: https://docs.python.org/3/library/webbrowser.html#index-3
# Scraping 373/11746: https://docs.python.org/3/library/select.html#index-5
# Scraping 374/11746: https://docs.python.org/3/library/wsgiref.html#wsgiref.handlers.BaseHandler.error_headers
# Scraping 375/11746: https://docs.python.org/3/library/contextvars.html#contextvars.ContextVar.reset
# Scraping 376/11746: https://docs.python.org/3/reference/datamodel.html#index-73
# Scraping 377/11746: https://docs.python.org/3/reference/lexical_analysis.html#index-25
# Scraping 378/11746: https://docs.python.org/3/library/io.html#io.BufferedReader.peek
# Scraping 379/11746: https://docs.python.org/3/library/curses.ascii.html#curses.ascii.isalnum
# Scraping 380/11746: https://docs.python.org/3/library/collections.html#collections.UserString.data
# Scraping 381/11746: https://docs.python.org/3/library/email.utils.html#email.utils.collapse_rfc2231_value
# Scraping 382/11746: https://docs.python.org/3/library/pathlib.html#pathlib.Path.hardlink_to
# Scraping 383/11746: https://docs.python.org/3/library/unittest.mock.html#unittest.mock.patch
# Scraping 384/11746: https://docs.python.org/3/library/curses.html#curses.KEY_SCOPY
# Scraping 385/11746: https://docs.python.org/3/library/ast.html#ast.TypeVar
# Scraping 386/11746: https://docs.python.org/3/library/os.html#os.WNOHANG
# Scraping 387/11746: https://docs.python.org/3/library/stat.html#stat.SF_RESTRICTED
# Scraping 388/11746: https://docs.python.org/3/library/bdb.html#bdb.Bdb.break_anywhere
# Scraping 389/11746: https://docs.python.org/3/library/sysconfig.html#sysconfig.get_config_var
# Scraping 390/11746: https://docs.python.org/3/library/urllib.parse.html#index-15
# Scraping 391/11746: https://docs.python.org/3/library/os.html#os.EX_USAGE
# Scraping 392/11746: https://docs.python.org/3/library/tty.html#tty.setcbreak
# Scraping 393/11746: https://docs.python.org/3/library/os.html#os.readlink
# Scraping 394/11746: https://docs.python.org/3/library/mailbox.html#mailbox.MaildirMessage.set_flags
# Scraping 395/11746: https://docs.python.org/3/library/xml.dom.html#xml.dom.Document.createAttributeNS
# Scraping 396/11746: https://docs.python.org/3/library/bz2.html#bz2.BZ2File.read1
# Scraping 397/11746: https://docs.python.org/3/reference/datamodel.html#codeobject.co_nlocals
# Scraping 398/11746: https://docs.python.org/3/library/functions.html#int
# Scraping 399/11746: https://docs.python.org/3/library/csv.html#csv.excel
# Scraping 400/11746: https://docs.python.org/3/library/http.client.html#index-2
# Scraping 401/11746: https://docs.python.org/3/library/os.html#os.setpriority
# Scraping 402/11746: https://docs.python.org/3/library/io.html#io.TextIOBase.tell
# Scraping 403/11746: https://docs.python.org/3/library/pickle.html#pickle.Pickler.reducer_override
# Scraping 404/11746: https://docs.python.org/3/library/symtable.html#symtable.SymbolTableType.TYPE_ALIAS
# Scraping 405/11746: https://docs.python.org/3/library/tarfile.html#tarfile.DIRTYPE
# Scraping 406/11746: https://docs.python.org/3/library/ssl.html#ssl.VERIFY_X509_STRICT
# Scraping 407/11746: https://docs.python.org/3/library/bdb.html#bdb.Bdb.runcall
# Scraping 408/11746: https://docs.python.org/3/library/email.message.html#email.message.EmailMessage.get_content_maintype
# Scraping 409/11746: https://docs.python.org/3/library/re.html#index-33
# Scraping 410/11746: https://docs.python.org/3/library/json.html#json.JSONDecodeError.doc
# Scraping 411/11746: https://docs.python.org/3/library/os.html#os.ttyname
# Scraping 412/11746: https://docs.python.org/3/library/codecs.html#codecs.getwriter
# Scraping 413/11746: https://docs.python.org/3/library/importlib.metadata.html#importlib.metadata.packages_distributions
# Scraping 414/11746: https://docs.python.org/3/library/__future__.html#index-8
# Scraping 415/11746: https://docs.python.org/3/library/readline.html#readline.get_history_item
# Scraping 416/11746: https://docs.python.org/3/library/stdtypes.html#str.isalpha
# Scraping 417/11746: https://docs.python.org/3/library/tkinter.dnd.html#tkinter.dnd.DndHandler
# Scraping 418/11746: https://docs.python.org/3/library/queue.html#queue.Queue
# Scraping 419/11746: https://docs.python.org/3/library/plistlib.html#plistlib.dumps
# Scraping 420/11746: https://docs.python.org/3/library/os.html#index-41
# Scraping 421/11746: https://docs.python.org/3/library/dbm.html#dbm.ndbm.error
# Scraping 422/11746: https://docs.python.org/3/library/stdtypes.html#str.isupper
# Scraping 423/11746: https://docs.python.org/3/library/argparse.html#argparse.FileType
# Scraping 424/11746: https://docs.python.org/3/library/asynchat.html#module-asynchat
# Scraping 425/11746: https://docs.python.org/3/library/random.html#random.seed
# Scraping 426/11746: https://docs.python.org/3/library/math.html#math.erfc
# Scraping 427/11746: https://docs.python.org/3/library/test.html#test.support.requires_bz2
# Scraping 428/11746: https://docs.python.org/3/library/email.mime.html#module-email.mime.audio
# Scraping 429/11746: https://docs.python.org/3/library/stat.html#stat.SF_FIRMLINK
# Scraping 430/11746: https://docs.python.org/3/library/turtle.html#turtle.tiltangle
# Scraping 431/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Progressbar.start
# Scraping 432/11746: https://docs.python.org/3/library/collections.abc.html#collections.abc.Set
# Scraping 433/11746: https://docs.python.org/3/library/email.header.html#email.header.Header.append
# Scraping 434/11746: https://docs.python.org/3/library/asyncio-task.html#asyncio.create_eager_task_factory
# Scraping 435/11746: https://docs.python.org/3/library/inspect.html#inspect.BoundArguments.kwargs
# Scraping 436/11746: https://docs.python.org/3/library/stdtypes.html#index-12
# Scraping 437/11746: https://docs.python.org/3/library/email.header.html#email.header.Header
# Scraping 438/11746: https://docs.python.org/3/library/curses.html#curses.noecho
# Scraping 439/11746: https://docs.python.org/3/library/warnings.html#warnings.formatwarning
# Scraping 440/11746: https://docs.python.org/3/library/os.html#os.ptsname
# Scraping 441/11746: https://docs.python.org/3/library/asyncio-stream.html#asyncio.start_server
# Scraping 442/11746: https://docs.python.org/3/library/platform.html#platform.node
# Scraping 443/11746: https://docs.python.org/3/library/email.parser.html#email.parser.BytesHeaderParser
# Scraping 444/11746: https://docs.python.org/3/library/enum.html#enum.FlagBoundary.STRICT
# Scraping 445/11746: https://docs.python.org/3/library/pickle.html#pickle.Pickler
# Scraping 446/11746: https://docs.python.org/3/library/http.html#index-58
# Scraping 447/11746: https://docs.python.org/3/reference/datamodel.html#object.__buffer__
# Scraping 448/11746: https://docs.python.org/3/library/xml.sax.reader.html#xml.sax.xmlreader.InputSource.setCharacterStream
# Scraping 449/11746: https://docs.python.org/3/library/pyexpat.html#xml.parsers.expat.errors.XML_ERROR_NO_MEMORY
# Scraping 450/11746: https://docs.python.org/3/library/turtle.html#turtle.exitonclick
# Scraping 451/11746: https://docs.python.org/3/library/curses.html#curses.flash
# Scraping 452/11746: https://docs.python.org/3/library/sys.html#sys.exec_prefix
# Scraping 453/11746: https://docs.python.org/3/library/zipfile.html#zipfile.ZipFile.extract
# Scraping 454/11746: https://docs.python.org/3/library/ctypes.html#ctypes.string_at
# Scraping 455/11746: https://docs.python.org/3/library/dis.html#opcode-DELETE_SUBSCR
# Scraping 456/11746: https://docs.python.org/3/library/warnings.html#index-5
# Scraping 457/11746: https://docs.python.org/3/library/gc.html#gc.is_tracked
# Scraping 458/11746: https://docs.python.org/3/library/tarfile.html#tarfile.SpecialFileError
# Scraping 459/11746: https://docs.python.org/3/library/pyexpat.html#xml.parsers.expat.xmlparser.ordered_attributes
# Scraping 460/11746: https://docs.python.org/3/library/ast.html#ast.TypeAlias
# Scraping 461/11746: https://docs.python.org/3/library/plistlib.html#index-0
# Scraping 462/11746: https://docs.python.org/3/library/stdtypes.html#bytearray.rfind
# Scraping 463/11746: https://docs.python.org/3/library/sys.monitoring.html#monitoring-event-EXCEPTION_HANDLED
# Scraping 464/11746: https://docs.python.org/3/library/operator.html#operator.__ixor__
# Scraping 465/11746: https://docs.python.org/3/library/os.html#os.confstr_names
# Scraping 466/11746: https://docs.python.org/3/library/errno.html#errno.ELIBMAX
# Scraping 467/11746: https://docs.python.org/3/reference/datamodel.html#frame.clear
# Scraping 468/11746: https://docs.python.org/3/library/pdb.html#pdb.run
# Scraping 469/11746: https://docs.python.org/3/library/bdb.html#bdb.BdbQuit
# Scraping 470/11746: https://docs.python.org/3/library/curses.html#curses.BUTTONn_CLICKED
# Scraping 471/11746: https://docs.python.org/3/library/email.parser.html#email.parser.BytesFeedParser.close
# Scraping 472/11746: https://docs.python.org/3/library/subprocess.html#subprocess.getstatusoutput
# Scraping 473/11746: https://docs.python.org/3/library/ast.html#ast.copy_location
# Scraping 474/11746: https://docs.python.org/3/library/zipapp.html#cmdoption-zipapp-h
# Scraping 475/11746: https://docs.python.org/3/library/reprlib.html#reprlib.Repr.maxlong
# Scraping 476/11746: https://docs.python.org/3/library/collections.html#collections.ChainMap.new_child
# Scraping 477/11746: https://docs.python.org/3/library/http.cookiejar.html#http.cookiejar.DefaultCookiePolicy.set_allowed_domains
# Scraping 478/11746: https://docs.python.org/3/library/os.html#os.WIFEXITED
# Scraping 479/11746: https://docs.python.org/3/library/math.html#math.atan2
# Scraping 480/11746: https://docs.python.org/3/library/email.headerregistry.html#email.headerregistry.ContentDispositionHeader.content_disposition
# Scraping 481/11746: https://docs.python.org/3/library/exceptions.html#ConnectionRefusedError
# Scraping 482/11746: https://docs.python.org/3/library/ast.html#ast.PyCF_TYPE_COMMENTS
# Scraping 483/11746: https://docs.python.org/3/library/decimal.html#decimal.Context.is_subnormal
# Scraping 484/11746: https://docs.python.org/3/library/xml.dom.html#xml.dom.NodeList.length
# Scraping 485/11746: https://docs.python.org/3/library/os.html#os.symlink
# Scraping 486/11746: https://docs.python.org/3/library/curses.html#curses.window.getkey
# Scraping 487/11746: https://docs.python.org/3/library/email.html#index-1
# Scraping 488/11746: https://docs.python.org/3/library/asyncio-sync.html#asyncio.Barrier.wait
# Scraping 489/11746: https://docs.python.org/3/library/gettext.html#index-7
# Scraping 490/11746: https://docs.python.org/3/library/test.html#test.support.socket_helper.find_unused_port
# Scraping 491/11746: https://docs.python.org/3/library/dbm.html#dbm.whichdb
# Scraping 492/11746: https://docs.python.org/3/library/poplib.html#poplib.POP3.capa
# Scraping 493/11746: https://docs.python.org/3/reference/simple_stmts.html#index-45
# Scraping 494/11746: https://docs.python.org/3/library/email.policy.html#email.policy.EmailPolicy.header_store_parse
# Scraping 495/11746: https://docs.python.org/3/library/traceback.html#index-1
# Scraping 496/11746: https://docs.python.org/3/library/tracemalloc.html#tracemalloc.DomainFilter
# Scraping 497/11746: https://docs.python.org/3/library/sqlite3.html#index-4
# Scraping 498/11746: https://docs.python.org/3/library/xml.etree.elementtree.html#xml.etree.ElementTree.ProcessingInstruction
# Scraping 499/11746: https://docs.python.org/3/library/dis.html#opcode-IMPORT_NAME
# Scraping 500/11746: https://docs.python.org/3/library/email.message.html#index-10
# Scraping 501/11746: https://docs.python.org/3/library/socket.html#socket.ETHERTYPE_ARP
# Scraping 502/11746: https://docs.python.org/3/library/http.html#index-63
# Scraping 503/11746: https://docs.python.org/3/library/os.html#os.supports_effective_ids
# Scraping 504/11746: https://docs.python.org/3/library/compileall.html#cmdoption-compileall-o
# Scraping 505/11746: https://docs.python.org/3/reference/expressions.html#index-29
# Scraping 506/11746: https://docs.python.org/3/library/unittest.mock.html#unittest.mock.AsyncMock.assert_awaited_with
# Scraping 507/11746: https://docs.python.org/3/library/operator.html#operator.iand
# Scraping 508/11746: https://docs.python.org/3/library/difflib.html#difflib.context_diff
# Scraping 509/11746: https://docs.python.org/3/library/operator.html#operator.not_
# Scraping 510/11746: https://docs.python.org/3/library/email.compat32-message.html#index-10
# Scraping 511/11746: https://docs.python.org/3/library/colorsys.html#colorsys.yiq_to_rgb
# Scraping 512/11746: https://docs.python.org/3/library/signal.html#signal.pthread_kill
# Scraping 513/11746: https://docs.python.org/3/library/ast.html#ast.ListComp
# Scraping 514/11746: https://docs.python.org/3/library/ast.html#index-2
# Scraping 515/11746: https://docs.python.org/3/library/warnings.html#warnings.simplefilter
# Scraping 516/11746: https://docs.python.org/3/library/typing.html#typing.NamedTuple
# Scraping 517/11746: https://docs.python.org/3/library/os.html#index-24
# Scraping 518/11746: https://docs.python.org/3/library/os.html#os.P_PGID
# Scraping 519/11746: https://docs.python.org/3/library/math.html#math.cbrt
# Scraping 520/11746: https://docs.python.org/3/library/platform.html#platform.freedesktop_os_release
# Scraping 521/11746: https://docs.python.org/3/library/multiprocessing.shared_memory.html#multiprocessing.managers.SharedMemoryManager
# Scraping 522/11746: https://docs.python.org/3/library/pyexpat.html#xml.parsers.expat.errors.XML_ERROR_INCOMPLETE_PE
# Scraping 523/11746: https://docs.python.org/3/library/stdtypes.html#memoryview
# Scraping 524/11746: https://docs.python.org/3/library/signal.html#signal.setitimer
# Scraping 525/11746: https://docs.python.org/3/library/os.html#index-8
# Scraping 526/11746: https://docs.python.org/3/library/uuid.html#cmdoption-uuid-h
# Scraping 527/11746: https://docs.python.org/3/library/email.headerregistry.html#email.headerregistry.HeaderRegistry.__getitem__
# Scraping 528/11746: https://docs.python.org/3/library/http.client.html#http.client.HTTPMessage
# Scraping 529/11746: https://docs.python.org/3/reference/datamodel.html#index-34
# Scraping 530/11746: https://docs.python.org/3/library/pprint.html#pprint.PrettyPrinter
# Scraping 531/11746: https://docs.python.org/3/library/http.cookiejar.html#http.cookiejar.Cookie.expires
# Scraping 532/11746: https://docs.python.org/3/library/msvcrt.html#msvcrt.ungetch
# Scraping 533/11746: https://docs.python.org/3/library/operator.html#operator.__not__
# Scraping 534/11746: https://docs.python.org/3/library/difflib.html#difflib.SequenceMatcher
# Scraping 535/11746: https://docs.python.org/3/library/dis.html#opcode-DELETE_NAME
# Scraping 536/11746: https://docs.python.org/3/library/tempfile.html#tempfile.mkdtemp
# Scraping 537/11746: https://docs.python.org/3/library/readline.html#readline.get_endidx
# Scraping 538/11746: https://docs.python.org/3/library/xml.sax.reader.html#module-xml.sax.xmlreader
# Scraping 539/11746: https://docs.python.org/3/library/ssl.html#index-15
# Scraping 540/11746: https://docs.python.org/3/library/reprlib.html#reprlib.Repr.maxdict
# Scraping 541/11746: https://docs.python.org/3/library/http.html#http.HTTPStatus
# ...
# Scraping 4060/11746: https://docs.python.org/3/library/curses.html#curses.ACS_SSSS
# Scraping 4061/11746: https://docs.python.org/3/library/platform.html#platform.java_ver
# Scraping 4062/11746: https://docs.python.org/3/library/token.html#token.tok_name
# Scraping 4063/11746: https://docs.python.org/3/library/bz2.html#bz2.BZ2Decompressor.decompress
# Scraping 4064/11746: https://docs.python.org/3/reference/datamodel.html#index-83
# Scraping 4065/11746: https://docs.python.org/3/library/pdb.html#pdb.Pdb
# Scraping 4066/11746: https://docs.python.org/3/library/optparse.html#optparse.OptionParser.parse_args
# Scraping 4067/11746: https://docs.python.org/3/library/xml.etree.elementtree.html#xml.etree.ElementTree.XMLPullParser.flush
# Scraping 4068/11746: https://docs.python.org/3/library/dis.html#opcode-HAVE_ARGUMENT
# Scraping 4069/11746: https://docs.python.org/3/library/mailbox.html#mailbox.MH.lock
# Scraping 4070/11746: https://docs.python.org/3/library/contextlib.html#contextlib.AsyncExitStack.aclose
# Scraping 4071/11746: https://docs.python.org/3/library/stringprep.html#stringprep.in_table_d1
# Scraping 4072/11746: https://docs.python.org/3/library/dialog.html#tkinter.filedialog.askdirectory
# Scraping 4073/11746: https://docs.python.org/3/library/io.html#io.TextIOBase.buffer
# Scraping 4074/11746: https://docs.python.org/3/library/os.html#os.removedirs
# Scraping 4075/11746: https://docs.python.org/3/library/asyncio-eventloop.html#asyncio.loop.default_exception_handler
# Scraping 4076/11746: https://docs.python.org/3/library/filecmp.html#filecmp.DEFAULT_IGNORES
# Scraping 4077/11746: https://docs.python.org/3/library/unittest.html#unittest.TestLoader.errors
# Scraping 4078/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Treeview.identify_column
# Scraping 4079/11746: https://docs.python.org/3/library/http.html#index-37
# Scraping 4080/11746: https://docs.python.org/3/library/http.html#index-6
# Scraping 4081/11746: https://docs.python.org/3/library/xml.dom.html#xml.dom.Node.nodeValue
# Scraping 4082/11746: https://docs.python.org/3/library/shlex.html#module-shlex
# Scraping 4083/11746: https://docs.python.org/3/library/typing.html#typing.Generator
# Scraping 4084/11746: https://docs.python.org/3/library/gettext.html#index-10
# Scraping 4085/11746: https://docs.python.org/3/library/locale.html#index-6
# Scraping 4086/11746: https://docs.python.org/3/library/time.html#time.struct_time.tm_sec
# Scraping 4087/11746: https://docs.python.org/3/reference/expressions.html#index-74
# Scraping 4088/11746: https://docs.python.org/3/library/stdtypes.html#memoryview.cast
# Scraping 4089/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Progressbar.stop
# Scraping 4090/11746: https://docs.python.org/3/library/unittest.html#cmdoption-unittest-locals
# Scraping 4091/11746: https://docs.python.org/3/library/http.cookiejar.html#http.cookiejar.Cookie.version
# Scraping 4092/11746: https://docs.python.org/3/library/multiprocessing.html#multiprocessing.pool.Pool.apply_async
# Scraping 4093/11746: https://docs.python.org/3/library/tarfile.html#tarfile.ExtractError
# Scraping 4094/11746: https://docs.python.org/3/reference/datamodel.html#function.__globals__
# Scraping 4095/11746: https://docs.python.org/3/library/dis.html#opcode-POP_TOP
# Scraping 4096/11746: https://docs.python.org/3/library/stat.html#stat.FILE_ATTRIBUTE_NORMAL
# Scraping 4097/11746: https://docs.python.org/3/library/http.server.html#http.server.SimpleHTTPRequestHandler.server_version
# Scraping 4098/11746: https://docs.python.org/3/library/json.html#module-json
# Scraping 4099/11746: https://docs.python.org/3/reference/datamodel.html#object.__mod__
# Scraping 4100/11746: https://docs.python.org/3/library/sqlite3.html#sqlite3.sqlite_version_info
# Scraping 4101/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Treeview.xview
# Scraping 4102/11746: https://docs.python.org/3/library/io.html#io.RawIOBase
# Scraping 4103/11746: https://docs.python.org/3/library/curses.html#curses.KEY_SREDO
# Scraping 4104/11746: https://docs.python.org/3/library/sqlite3.html#sqlite3.Cursor.connection
# Scraping 4105/11746: https://docs.python.org/3/library/errno.html#errno.EKEYREJECTED
# Scraping 4106/11746: https://docs.python.org/3/reference/datamodel.html#index-66
# Scraping 4107/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Style.layout
# Scraping 4108/11746: https://docs.python.org/3/library/inspect.html#inspect.BufferFlags.C_CONTIGUOUS
# Scraping 4109/11746: https://docs.python.org/3/library/os.html#os.F_OK
# Scraping 4110/11746: https://docs.python.org/3/library/unittest.html#unittest.TestCase.assertNotIsInstance
# Scraping 4111/11746: https://docs.python.org/3/library/pdb.html#pdbcommand-display
# Scraping 4112/11746: https://docs.python.org/3/library/sys.html#sys.builtin_module_names
# Scraping 4113/11746: https://docs.python.org/3/library/cmath.html#cmath.rect
# Scraping 4114/11746: https://docs.python.org/3/library/email.message.html#index-8
# Scraping 4115/11746: https://docs.python.org/3/library/base64.html#index-11
# Scraping 4116/11746: https://docs.python.org/3/library/code.html#code.InteractiveInterpreter.runsource
# Scraping 4117/11746: https://docs.python.org/3/library/unittest.mock.html#unittest.mock.MagicMock
# Scraping 4118/11746: https://docs.python.org/3/library/unittest.html#cmdoption-unittest-discover-t
# Scraping 4119/11746: https://docs.python.org/3/library/http.html#index-24
# Scraping 4120/11746: https://docs.python.org/3/library/os.html#os.terminal_size
# Scraping 4121/11746: https://docs.python.org/3/library/asyncio-task.html#asyncio.as_completed
# Scraping 4122/11746: https://docs.python.org/3/library/ipaddress.html#ipaddress.IPv4Network.is_private
# Scraping 4123/11746: https://docs.python.org/3/library/ast.html#ast.AST
# Scraping 4124/11746: https://docs.python.org/3/library/errno.html#errno.ENODATA
# Scraping 4125/11746: https://docs.python.org/3/library/base64.html#base64.z85encode
# Scraping 4126/11746: https://docs.python.org/3/library/asyncio-task.html#asyncio.Task.uncancel
# Scraping 4127/11746: https://docs.python.org/3/library/asyncio-sync.html#asyncio.Condition.release
# Scraping 4128/11746: https://docs.python.org/3/library/stdtypes.html#memoryview.nbytes
# Scraping 4129/11746: https://docs.python.org/3/library/gc.html#gc.isenabled
# Scraping 4130/11746: https://docs.python.org/3/library/gc.html#gc.set_threshold
# Scraping 4131/11746: https://docs.python.org/3/library/bdb.html#bdb.Bdb.get_all_breaks
# Scraping 4132/11746: https://docs.python.org/3/library/multiprocessing.html#multiprocessing.Process.pid
# Scraping 4133/11746: https://docs.python.org/3/library/functools.html#functools.lru_cache
# Scraping 4134/11746: https://docs.python.org/3/library/dis.html#opcode-RETURN_VALUE
# Scraping 4135/11746: https://docs.python.org/3/library/inspect.html#inspect.isdatadescriptor
# Scraping 4136/11746: https://docs.python.org/3/library/functions.html#zip
# Scraping 4137/11746: https://docs.python.org/3/library/ssl.html#ssl.RAND_status
# Scraping 4138/11746: https://docs.python.org/3/library/_thread.html#thread.TIMEOUT_MAX
# Scraping 4139/11746: https://docs.python.org/3/library/operator.html#operator.__and__
# Scraping 4140/11746: https://docs.python.org/3/library/codecs.html#codecs.CodecInfo.encode
# Scraping 4141/11746: https://docs.python.org/3/library/select.html#select.epoll.unregister
# Scraping 4142/11746: https://docs.python.org/3/library/dis.html#dis.findlinestarts
# Scraping 4143/11746: https://docs.python.org/3/library/sys.html#sys.argv
# Scraping 4144/11746: https://docs.python.org/3/library/logging.handlers.html#logging.handlers.SysLogHandler.emit
# Scraping 4145/11746: https://docs.python.org/3/library/sqlite3.html#sqlite3.Cursor.description
# Scraping 4146/11746: https://docs.python.org/3/library/curses.html#curses.textpad.Textbox.gather
# Scraping 4147/11746: https://docs.python.org/3/library/heapq.html#heapq.heappushpop
# Scraping 4148/11746: https://docs.python.org/3/library/ftplib.html#ftplib.FTP.mlsd
# Scraping 4149/11746: https://docs.python.org/3/library/operator.html#operator.__ipow__
# Scraping 4150/11746: https://docs.python.org/3/library/logging.handlers.html#index-0
# Scraping 4151/11746: https://docs.python.org/3/library/os.html#os.spawnlpe
# Scraping 4152/11746: https://docs.python.org/3/reference/expressions.html#index-14
# Scraping 4153/11746: https://docs.python.org/3/library/pathlib.html#pathlib.Path.is_socket
# Scraping 4154/11746: https://docs.python.org/3/library/profile.html#index-0
# Scraping 4155/11746: https://docs.python.org/3/library/codecs.html#codecs.IncrementalDecoder.getstate
# Scraping 4156/11746: https://docs.python.org/3/library/http.cookiejar.html#http.cookiejar.MozillaCookieJar
# Scraping 4157/11746: https://docs.python.org/3/library/tkinter.ttk.html#tkinter.ttk.Notebook
# Scraping 4158/11746: https://docs.python.org/3/reference/datamodel.html#index-70
# Scraping 4159/11746: https://docs.python.org/3/library/dis.html#module-dis
# Scraping 4160/11746: https://docs.python.org/3/library/curses.html#curses.has_key
# Scraping 4161/11746: https://docs.python.org/3/library/asyncio-stream.html#asyncio.StreamReader.readuntil
# Scraping 4162/11746: https://docs.python.org/3/library/http.cookiejar.html#http.cookiejar.FileCookieJar.save
# Scraping 4163/11746: https://docs.python.org/3/library/ossaudiodev.html#module-ossaudiodev
# Scraping 4164/11746: https://docs.python.org/3/library/tarfile.html#tarfile.TarInfo.frombuf
# Scraping 4165/11746: https://docs.python.org/3/reference/simple_stmts.html#index-48
# Scraping 4166/11746: https://docs.python.org/3/library/ssl.html#ssl.OP_ALL
# Scraping 4167/11746: https://docs.python.org/3/library/runpy.html#module-runpy
# Scraping 4168/11746: https://docs.python.org/3/library/mailbox.html#mailbox.ExternalClashError
# Scraping 4169/11746: https://docs.python.org/3/library/os.html#os.execl
# Scraping 4170/11746: https://docs.python.org/3/library/xml.sax.reader.html#xml.sax.xmlreader.IncrementalParser.close
# Scraping 4171/11746: https://docs.python.org/3/library/turtle.html#turtle.ht
# Scraping 4172/11746: https://docs.python.org/3/library/json.html#json.JSONDecodeError.colno
# Scraping 4173/11746: https://docs.python.org/3/library/select.html#select.devpoll
# Scraping 4174/11746: https://docs.python.org/3/library/pyexpat.html#xml.parsers.expat.xmlparser.SetBase
# Scraping 4175/11746: https://docs.python.org/3/library/sys.html#module-sys
# Scraping 4176/11746: https://docs.python.org/3/library/http.cookiejar.html#http.cookiejar.FileCookieJar.revert
# Scraping 4177/11746: https://docs.python.org/3/library/wsgiref.html#wsgiref.simple_server.WSGIServer.set_app
# Scraping 4178/11746: https://docs.python.org/3/library/contextlib.html#contextlib.AbstractAsyncContextManager
# Scraping 4179/11746: https://docs.python.org/3/library/ctypes.html#ctypes.c_time_t
# Scraping 4180/11746: https://docs.python.org/3/library/subprocess.html#subprocess.CREATE_BREAKAWAY_FROM_JOB
# Scraping 4181/11746: https://docs.python.org/3/library/curses.html#curses.window.deleteln
# Scraping 4182/11746: https://docs.python.org/3/library/curses.html#curses.ACS_DEGREE
# Scraping 4183/11746: https://docs.python.org/3/library/turtle.html#turtle.TurtleScreen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 88
#      86 # Run the scraper
#      87 if __name__ == "__main__":
# ---> 88     scrape_and_save()
#
# Cell In[22], line 76, in scrape_and_save()
#      74 for i, url in enumerate(doc_links):
#      75     print(f"Scraping {i+1}/{len(doc_links)}: {url}")
# ---> 76     title, content = scrape_page(url)
#      77     if content:
#      78         filename = f"{title.replace(' ', '_').replace('/', '_')}.txt"
#
# Cell In[22], line 62, in scrape_page(url)
#      60 # Extract content (paragraphs, lists, code)
#      61 content = ""
# ---> 62 for para in soup.select("p, li, pre"):  # Extract paragraphs, lists, and code blocks
#      63     text = para.get_text(separator=" ", strip=True)
#      64     text = clean_text(text)  # Fix extra newlines
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\element.py:2116, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    2096 def select(self, selector, namespaces=None, limit=None, **kwargs):
#    2097     """Perform a CSS selection operation on the current element.
#    2098
#    2099     This uses the SoupSieve library.
#    (...)
#    2114     :rtype: bs4.element.ResultSet
#    2115     """
# -> 2116     return self.css.select(selector, namespaces, limit, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\css.py:162, in CSS.select(self, select, namespaces, limit, flags, **kwargs)
#     158 if limit is None:
#     159     limit = 0
#     161 return self._rs(
# --> 162     self.api.select(
#     163         select, self.tag, self._ns(namespaces, select), limit, flags,
#     164         **kwargs
#     165     )
#     166 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\__init__.py:147, in select(select, tag, namespaces, limit, flags, custom, **kwargs)
#     135 def select(
#     136     select: str,
#     137     tag: bs4.Tag,
#    (...)
#     143     **kwargs: Any
#     144 ) -> list[bs4.Tag]:
#     145     """Select the specified tags."""
# --> 147     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_match.py:1564, in SoupSieve.select(self, tag, limit)
#    1561 def select(self, tag: bs4.Tag, limit: int = 0) -> list[bs4.Tag]:
#    1562     """Select the specified tags."""
# -> 1564     return list(self.iselect(tag, limit))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_match.py:1569, in SoupSieve.iselect(self, tag, limit)
#    1566 def iselect(self, tag: bs4.Tag, limit: int = 0) -> Iterator[bs4.Tag]:
#    1567     """Iterate the specified tags."""
# -> 1569     yield from CSSMatch(self.selectors, tag, self.namespaces, self.flags).select(limit)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_match.py:1469, in CSSMatch.select(self, limit)
#    1466 lim = None if limit < 1 else limit
#    1468 for child in self.get_descendants(self.tag):
# -> 1469     if self.match(child):
#    1470         yield child
#    1471         if lim is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_match.py:1496, in CSSMatch.match(self, el)
#    1493 def match(self, el: bs4.Tag) -> bool:
#    1494     """Match."""
# -> 1496     return not self.is_doc(el) and self.is_tag(el) and self.match_selectors(el, self.selectors)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_match.py:1400, in CSSMatch.match_selectors(self, el, selectors)
#    1398     continue
#    1399 # Verify tag matches
# -> 1400 if not self.match_tag(el, selector.tag):
#    1401     continue
#    1402 # Verify tag is defined
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_match.py:759, in CSSMatch.match_tag(self, el, tag)
#     756 match = True
#     757 if tag is not None:
#     758     # Verify namespace
# --> 759     if not self.match_namespace(el, tag):
#     760         match = False
#     761     if not self.match_tagname(el, tag):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_match.py:708, in CSSMatch.match_namespace(self, el, tag)
#     705 """Match the namespace of the element."""
#     707 match = True
# --> 708 namespace = self.get_tag_ns(el)
#     709 default_namespace = self.namespaces.get('')
#     710 tag_ns = '' if tag.prefix is None else self.namespaces.get(tag.prefix)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_match.py:530, in CSSMatch.get_tag_ns(self, el)
#     526     """Check if namespaces are supported in the HTML type."""
#     528     return self.is_xml or self.has_html_namespace
# --> 530 def get_tag_ns(self, el: bs4.Tag) -> str:
#     531     """Get tag namespace."""
#     533     if self.supports_namespaces():
#
# KeyboardInterrupt:

# %% [markdown]
# Les fichiers sont structures, on utilise le Recursive Chunking avec un decompte de Tokens.

# %%
checkpoint = 'sentence-transformers/all-mpnet-base-v2'
model = AutoModel.from_pretrained(checkpoint)
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# %%
def token_splitting(text):
    tokens = tokenizer.encode(text)
    return len(tokens)

# %% [markdown]
# La taille maximale d'entree pour le modele qu'on va utiliser pour les embeddings est 384 tokens.

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,  
    chunk_overlap=50,  
    length_function=token_splitting,
    separators = ["\n\n","\n",".","?","!"," ",""]
)

# %%
# DATA_FOLDER = "python_docs_cleaned"
# FAISS_INDEX_PATH = "faiss_index.bin"
# META_PATH = "faiss_metadata.txt"
# CHUNKS_PATH = "faiss_chunks.json"

# def get_embedding(text):
#     inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=384)  
#     outputs = model(**inputs)
#     return torch.mean(outputs.last_hidden_state, axis=1).detach().numpy().squeeze(0).astype(np.float32)  


# dimension = model.config.hidden_size
# index = faiss.IndexFlatIP(dimension)  
# metadata = []
# chunks_data = {}  
# chunk_id = 0

# for filename in tqdm(os.listdir(DATA_FOLDER), desc="Processing Files", unit="file"):
#     if filename.endswith(".txt"):
#         file_path = os.path.join(DATA_FOLDER, filename)
        
#         with open(file_path, "r", encoding="utf-8") as f:
#             text = f.read()
        
#         chunks = splitter.split_text(text) 
        
#         for chunk in tqdm(chunks, desc=f"Embedding {filename}", unit="chunk", leave=False):
#             embedding = get_embedding(chunk)  
#             faiss.normalize_L2(embedding.reshape(1, -1)) 
#             index.add(embedding.reshape(1, -1)) 
#             metadata.append(f"{chunk_id}\t{filename}\n")  
#             chunks_data[chunk_id] = chunk  
#             chunk_id += 1  

# faiss.write_index(index, FAISS_INDEX_PATH)

# with open(META_PATH, "w", encoding="utf-8") as f:
#     f.writelines(metadata)

# with open(CHUNKS_PATH, "w", encoding="utf-8") as f:
#     json.dump(chunks_data, f, ensure_ascii=False, indent=4) 

# print("FAISS index, metadata, and chunks saved successfully!")
# Out:
# Processing Files:   0%|                                                                      | 0/281 [00:00<?, ?file/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:   0%|                                  | 0/17 [00:00<?, ?chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:   6%|█▌                        | 1/17 [00:01<00:17,  1.09s/chunk]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  12%|███                       | 2/17 [00:01<00:08,  1.74chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  18%|████▌                     | 3/17 [00:01<00:06,  2.29chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  24%|██████                    | 4/17 [00:01<00:04,  2.86chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  29%|███████▋                  | 5/17 [00:02<00:03,  3.07chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  35%|█████████▏                | 6/17 [00:02<00:03,  3.31chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  41%|██████████▋               | 7/17 [00:02<00:02,  3.40chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  47%|████████████▏             | 8/17 [00:02<00:02,  3.82chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  53%|█████████████▊            | 9/17 [00:03<00:02,  3.66chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  59%|██████████████▋          | 10/17 [00:03<00:01,  3.72chunk/s]
# Embedding 10.Brief_Tour_of_the_Standard_Library¶.txt:  65%|████████████████▏        | 11/17 [00:03<00:01,  4.01chunk/s]
# Processing Files:   0%|                                                                      | 0/281 [00:03<?, ?file/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 28
#      25 chunks = splitter.split_text(text)
#      27 for chunk in tqdm(chunks, desc=f"Embedding {filename}", unit="chunk", leave=False):
# ---> 28     embedding = get_embedding(chunk)
#      29     faiss.normalize_L2(embedding.reshape(1, -1))
#      30     index.add(embedding.reshape(1, -1))
#
# Cell In[5], line 8, in get_embedding(text)
#       6 def get_embedding(text):
#       7     inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=384)
# ----> 8     outputs = model(**inputs)
#       9     return torch.mean(outputs.last_hidden_state, axis=1).detach().numpy().squeeze(0).astype(np.float32)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:544, in MPNetModel.forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     542 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     543 embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 544 encoder_outputs = self.encoder(
#     545     embedding_output,
#     546     attention_mask=extended_attention_mask,
#     547     head_mask=head_mask,
#     548     output_attentions=output_attentions,
#     549     output_hidden_states=output_hidden_states,
#     550     return_dict=return_dict,
#     551 )
#     552 sequence_output = encoder_outputs[0]
#     553 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:334, in MPNetEncoder.forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     331 if output_hidden_states:
#     332     all_hidden_states = all_hidden_states + (hidden_states,)
# --> 334 layer_outputs = layer_module(
#     335     hidden_states,
#     336     attention_mask,
#     337     head_mask[i],
#     338     position_bias,
#     339     output_attentions=output_attentions,
#     340     **kwargs,
#     341 )
#     342 hidden_states = layer_outputs[0]
#     344 if output_attentions:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:304, in MPNetLayer.forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     301 outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#     303 intermediate_output = self.intermediate(attention_output)
# --> 304 layer_output = self.output(intermediate_output, attention_output)
#     305 outputs = (layer_output,) + outputs
#     306 return outputs
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\models\mpnet\modeling_mpnet.py:273, in MPNetOutput.forward(self, hidden_states, input_tensor)
#     271 hidden_states = self.dense(hidden_states)
#     272 hidden_states = self.dropout(hidden_states)
# --> 273 hidden_states = self.LayerNorm(hidden_states + input_tensor)
#     274 return hidden_states
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\normalization.py:217, in LayerNorm.forward(self, input)
#     216 def forward(self, input: Tensor) -> Tensor:
# --> 217     return F.layer_norm(
#     218         input, self.normalized_shape, self.weight, self.bias, self.eps
#     219     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\functional.py:2910, in layer_norm(input, normalized_shape, weight, bias, eps)
#    2900 if has_torch_function_variadic(input, weight, bias):
#    2901     return handle_torch_function(
#    2902         layer_norm,
#    2903         (input, weight, bias),
#    (...)
#    2908         eps=eps,
#    2909     )
# -> 2910 return torch.layer_norm(
#    2911     input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled
#    2912 )
#
# KeyboardInterrupt:

# %% [markdown]
# Voici comment re utiliser les Embeddings apres avoir arreter Notebook

# %%
index = faiss.read_index(FAISS_INDEX_PATH)

with open(META_PATH, "r", encoding="utf-8") as f:
    metadata = [line.strip().split("\t") for line in f.readlines()] 

with open(CHUNKS_PATH, "r", encoding="utf-8") as f:
    chunks_data = json.load(f) 

print("FAISS index, metadata, and chunks restored successfully!")
# Out:
# FAISS index, metadata, and chunks restored successfully!

# %%
def search(query, top_k=5):
    query_embedding = get_embedding(query).reshape(1, -1)
    faiss.normalize_L2(query_embedding) 
    
    distances, indices = index.search(query_embedding, top_k)  
    
    results = []
    for idx, score in zip(indices[0], distances[0]):  
        if str(idx) in chunks_data: 
            chunk_text = chunks_data[str(idx)]
            
            for meta_id, filename in metadata:
                if int(meta_id) == idx:
                    results.append({
                        "chunk": chunk_text,
                        "score": score,
                        "source": filename
                    })
                    break
        else:
            print(f"⚠️ Warning: FAISS returned invalid index {idx}, skipping.")

    return results


query = "How to read a CSV in Python"
results = search(query)

for i, result in enumerate(results):
    chunk = result["chunk"]
    score = result["score"]
    source = result["source"]
    
    print(f"Result {i+1}: (Score: {score})")
    print(f"Source: {source}")
    print(f"{chunk}\n")
# Out:
# Result 1: (Score: 0.7100214958190918)
# The csv module's reader and writer objects read and write sequences.  Programmers can also read and write data in dictionary form using the DictReader and DictWriter classes.
#
# See also
#
# The Python Enhancement Proposal which proposed this addition to Python.
#
# The csv module defines the following functions:
#
# Return a reader object that will process lines from the given csvfile .  A csvfile must be an iterable of strings, each in the reader's defined csv format. A csvfile is most commonly a file-like object or list. If csvfile is a file object, it should be opened with newline='' . [ 1 ] An optional dialect parameter can be given which is used to define a set of parameters specific to a particular CSV dialect.  It may be an instance of a subclass of the Dialect class or one of the strings returned by the list_dialects() function.  The other optional fmtparams keyword arguments can be given to override individual formatting parameters in the current dialect.  For full details about the dialect and formatting parameters, see section Dialects and Formatting Parameters .
#
# Result 2: (Score: 0.6612316370010376)
# A slightly more advanced use of the reader — catching and reporting errors:
#
# import csv , sys filename = 'some.csv' with open ( filename , newline = '' ) as f : reader = csv . reader ( f ) try : for row in reader : print ( row ) except csv . Error as e : sys . exit ( 'file {} , line {} : {} ' . format ( filename , reader . line_num , e ))
#
# And while the module doesn't directly support parsing strings, it can easily be done:
#
# import csv for row in csv . reader ([ 'one,two,three' ]): print ( row )
#
# Footnotes
#
# If newline='' is not specified, newlines embedded inside quoted fields will not be interpreted correctly, and on platforms that use \r\n linendings on write an extra \r will be added.  It should always be safe to specify newline='' , since the csv module does its own ( universal ) newline handling.
#
# csv — CSV File Reading and Writing Module Contents Dialects and Formatting Parameters Reader Objects Writer Objects Examples
#
# Module Contents
#
# Dialects and Formatting Parameters
#
# Reader Objects
#
# Writer Objects
#
# Result 3: (Score: 0.6184734106063843)
# Each row read from the csv file is returned as a list of strings.  No automatic data type conversion is performed unless the QUOTE_NONNUMERIC format option is specified (in which case unquoted fields are transformed into floats).
#
# A short usage example:
#
# >>> import csv >>> with open ( 'eggs.csv' , newline = '' ) as csvfile : ... spamreader = csv . reader ( csvfile , delimiter = ' ' , quotechar = '|' ) ... for row in spamreader : ... print ( ', ' . join ( row )) Spam, Spam, Spam, Spam, Spam, Baked Beans Spam, Lovely Spam, Wonderful Spam
#
# Result 4: (Score: 0.6174153089523315)
# Title: csv— CSV File Reading and Writing¶
# URL: https://docs.python.org/3/library/csv.html#csv.csvwriter.writerow
#
# csv — CSV File Reading and Writing Module Contents Dialects and Formatting Parameters Reader Objects Writer Objects Examples
#
# Module Contents
#
# Dialects and Formatting Parameters
#
# Reader Objects
#
# Writer Objects
#
# Examples
#
# File Formats
#
# configparser — Configuration file parser
#
# Report a Bug
#
# Show Source
#
# index
#
# modules |
#
# next |
#
# previous |
#
#
#
# Python »
#
#
#
#
#
# 3.13.2 Documentation »
#
# The Python Standard Library »
#
# File Formats »
#
# csv — CSV File Reading and Writing
#
# |
#
# Theme Auto Light Dark |
#
# Source code: Lib/csv.py
#
# Result 5: (Score: 0.6015879511833191)
# Note
#
# This method is a rough heuristic and may produce both false positives and negatives.
#
# An example for Sniffer use:
#
# with open ( 'example.csv' , newline = '' ) as csvfile : dialect = csv . Sniffer () . sniff ( csvfile . read ( 1024 )) csvfile . seek ( 0 ) reader = csv . reader ( csvfile , dialect ) # ... process CSV file contents here ...
#
# The csv module defines the following constants:
#
# Instructs writer objects to quote all fields.
#
# Instructs writer objects to only quote those fields which contain special characters such as delimiter , quotechar or any of the characters in lineterminator .
#
# Instructs writer objects to quote all non-numeric fields.
#
# Instructs reader objects to convert all non-quoted fields to type float .
#
# Instructs writer objects to never quote fields.  When the current delimiter occurs in output data it is preceded by the current escapechar character.  If escapechar is not set, the writer will raise Error if any characters that require escaping are encountered.

# %% [markdown]
# On va definir une fonction qui permet de garder uniquement les entrees liees a la programmation python.

# %%
classifier = pipeline('zero-shot-classification')
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
labels = ['Not Python programming','Python programming']

# %%
def filter_input(input):
    results = classifier(input, candidate_labels = labels)
    if results['labels'][0] == 'Not Python programming':
        return 'Please make sure the question is related to Python Programming'
    return input

# %%
def filter_input(input):
    """
    Uses zero-shot classification to ensure the query is Python-related.
    """
    results = classifier(input, candidate_labels=labels)
    if results['labels'][0] == 'Not Python programming':
        return 'Please make sure the question is related to Python Programming'
    return input

def query_llama(context, question):
    if not context.strip():  
        return "Sorry, I couldn't find any relevant information in the database."

    prompt = f"""You are an AI assistant specialized in Python programming.
Answer the following question **strictly** using the provided context. 
Use phrases like "As stated in the document..." or include direct quotes in your response.

If the context does not contain an answer, say: "I don't have enough information to answer this question."

**Context:**
{context}

**Question:**
{question}
"""

    response = ollama.chat(model="llama2", messages=[{"role": "user", "content": prompt}])
    return response["message"]["content"]



def answer_query(user_query, top_k=5, threshold=0.6):
    filtered_query = filter_input(user_query)

    if "Please make sure" in filtered_query:
        return filtered_query  

    results = search(filtered_query, top_k=top_k)

    relevant_chunks = [r for r in results if r["score"] >= threshold]

    if not relevant_chunks: 
        return "Sorry, I couldn't find any relevant information in the database."

    context = "\n\n".join([r["chunk"] for r in relevant_chunks])
    sources = set(r["source"] for r in relevant_chunks)

    response = query_llama(context, user_query)

    final_output = f"{response}\n\nSources used:\n" + "\n".join(sources)
    return final_output

# %%
query = "How do I use OpenAI's GPT-4 API with streaming responses in Python?"
response = answer_query(query)

print("Assistant Response:\n")
print(response)
# Out:
# 💬 Assistant Response:
#
# Sorry, I couldn't find any relevant information in the database.

# %%
query = "What is the capital of France ?"
response = answer_query(query)

print("Assistant Response:\n")
print(response)
# Out:
# 💬 Assistant Response:
#
# Please make sure the question is related to Python Programming

# %%
query = "How to read a CSV file in python ?"
response = answer_query(query)
print("\nResponse:\n")
print(response)
# Out:
# 💬 Assistant Response:
#
# To read a CSV file in Python using the `csv` module, you can use the `reader()` function. Here is an example of how to do it:
# ```
# import csv
#
# with open('example.csv', newline='') as csvfile:
#     reader = csv.reader(csvfile)
#     for row in reader:
#         print(row)
# ```
# This code will read the contents of the `example.csv` file and print each row to the console. You can also use the `DictReader()` class to read CSV files in dictionary form:
# ```
# import csv
#
# with open('example.csv', newline='') as csvfile:
#     reader = csv.DictReader(csvfile)
#     for row in reader:
#         print(row)
# ```
# Alternatively, you can use the `csv.reader()` function with a file-like object, such as a `StringIO` object:
# ```
# import csv
#
# stringio = StringIO()
# with open('example.csv', newline='') as csvfile:
#     csv.reader(csvfile, stringio)
#     print(stringio.getvalue())
# ```
# Note that if the CSV file does not have a specified newline character (`newline=''`), then on some platforms (such as Windows) the `csv` module will append an extra `\r` character to the end of each line when writing. To avoid this, you can specify `newline=''` when opening the file, or use the ` csv.writer()` function with the `unicode` parameter set to `True`.
